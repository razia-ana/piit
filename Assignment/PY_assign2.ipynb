# %% [markdown]
# # Assignment - PY/02
# - Lambda Functions

# %%
import pandas as pd
from pydataset import data
from functools import reduce
# Load mtcars dataset
df = data('mtcars')

# %%
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %% [markdown]
# ### 4.1 Add Two Columns
# - Create a new column mpg_hp_sum = mpg + hp using a lambda function.

# %%
df['mpg_hp_sum'] = df. apply (lambda r: r['mpg'] + r['hp'], axis=1)

# %%
df['mpg_hp_sum']
# Out:
# Mazda RX4              131.0
# Mazda RX4 Wag          131.0
# Datsun 710             115.8
# Hornet 4 Drive         131.4
# Hornet Sportabout      193.7
# Valiant                123.1
# Duster 360             259.3
# Merc 240D               86.4
# Merc 230               117.8
# Merc 280               142.2
# Merc 280C              140.8
# Merc 450SE             196.4
# Merc 450SL             197.3
# Merc 450SLC            195.2
# Cadillac Fleetwood     215.4
# Lincoln Continental    225.4
# Chrysler Imperial      244.7
# Fiat 128                98.4
# Honda Civic             82.4
# Toyota Corolla          98.9
# Toyota Corona          118.5
# Dodge Challenger       165.5
# AMC Javelin            165.2
# Camaro Z28             258.3
# Pontiac Firebird       194.2
# Fiat X1-9               93.3
# Porsche 914-2          117.0
# Lotus Europa           143.4
# Ford Pantera L         279.8
# Ferrari Dino           194.7
# Maserati Bora          350.0
# Volvo 142E             130.4
# Name: mpg_hp_sum, dtype: float64

# %% [markdown]
# ### 4.2 Conditional Label
# - Create a new column mpg_label:
# 	•	"High" if mpg > 20
# 	•	"Low" otherwise
# - Use apply() with a lambda.

# %%
df['mpg_label'] = df["mpg"].apply (lambda r: 'High' if r > 20 else 'Low')  
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb  mpg_hp_sum mpg_label
# Mazda RX4             4       131.0      High
# Mazda RX4 Wag         4       131.0      High
# Datsun 710            1       115.8      High
# Hornet 4 Drive        1       131.4      High
# Hornet Sportabout     2       193.7       Low

# %% [markdown]
# ### 4.3 Multiply Column Values
# - Double all hp values using map() with a lambda.

# %%
df['hp'] = df['hp'].map(lambda x: x * 2)
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  220  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  220  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0  186  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  220  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  350  3.15  3.440  17.02   0   0     3
#
#                    carb  mpg_hp_sum mpg_label
# Mazda RX4             4       131.0      High
# Mazda RX4 Wag         4       131.0      High
# Datsun 710            1       115.8      High
# Hornet 4 Drive        1       131.4      High
# Hornet Sportabout     2       193.7       Low

# %%
## df['hp'] = df['hp'].apply(lambda x: x * 2)
#df.head()

# %%
#df.map(lambda x: x * 2)

# %% [markdown]
# ### 4.4 Filter Rows
# - Get a list of all mpg values greater than 25 using filter() with a lambda.

# %%
 list(filter(lambda x: x > 25, df['mpg']))
# Out:
# [32.4, 30.4, 33.9, 27.3, 26.0, 30.4]

# %% [markdown]
# ### 4.5 Reduce to Total
# - Use reduce() with a lambda to sum all cyl values in the dataset.

# %%
reduce (lambda x, y: x + y, df['cyl'])
# Out:
# 198

# %% [markdown]
# ### 4.6 Sort by Custom Rule
# - Sort the dataset by the reverse of the car names’ length using sorted() with a lambda on the index.

# %%
df.loc[sorted(df.index, key= lambda x: len(x), reverse =True)]
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
#
# Dodge Challenger        2       165.5       Low
# Pontiac Firebird        2       194.2       Low
# Hornet 4 Drive          1       131.4      High
# Toyota Corolla          1        98.9      High
# Ford Pantera L          4       279.8       Low
# Mazda RX4 Wag           4       131.0      High
# Toyota Corona           1       118.5      High
# Porsche 914-2           2       117.0      High
# Maserati Bora           8       350.0       Low
# Lotus Europa            2       143.4      High
# Ferrari Dino            6       194.7       Low
# Merc 450SLC             3       195.2       Low
# Honda Civic             2        82.4      High
# AMC Javelin             2       165.2       Low
# Datsun 710              1       115.8      High
# Duster 360              4       259.3       Low
# Merc 450SE              3       196.4       Low
# Merc 450SL              3       197.3       Low
# Camaro Z28              4       258.3       Low
# Volvo 142E              2       130.4      High
# Mazda RX4               4       131.0      High
# Merc 240D               2        86.4      High
# Merc 280C               4       140.8       Low
# Fiat X1-9               1        93.3      High
# Merc 230                2       117.8      High
# Merc 280                4       142.2       Low
# Fiat 128                1        98.4      High
# Valiant                 1       123.1       Low

# %% [markdown]
# ### 4.7 Multi-Column Condition
# - Create a column efficient_power = "Yes" if mpg > 20 and hp > 100, else "No".|

# %%
df['efficient_power'] = df.apply(lambda row: 'Yes' if row['mpg'] > 20 and row['hp'] > 100 else 'No', axis=1)
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  220  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  220  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0  186  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  220  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  350  3.15  3.440  17.02   0   0     3
#
#                    carb  mpg_hp_sum mpg_label efficient_power
# Mazda RX4             4       131.0      High             Yes
# Mazda RX4 Wag         4       131.0      High             Yes
# Datsun 710            1       115.8      High             Yes
# Hornet 4 Drive        1       131.4      High             Yes
# Hornet Sportabout     2       193.7       Low              No

# %% [markdown]
# ### 4.8 Normalize a Column
# - Normalize mpg between 0 and 1 using a lambda inside apply():
# - {normalized} = (x - min)/(max - min)

# %%
min_mpg = df['mpg'].min()
max_mpg = df['mpg'].max()

df['mpg_normalized'] = df['mpg'].apply(lambda x: (x - min_mpg) / (max_mpg - min_mpg))
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  220  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  220  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0  186  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  220  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  350  3.15  3.440  17.02   0   0     3
#
#                    carb  mpg_hp_sum mpg_label efficient_power  mpg_normalized
# Mazda RX4             4       131.0      High             Yes        0.451064
# Mazda RX4 Wag         4       131.0      High             Yes        0.451064
# Datsun 710            1       115.8      High             Yes        0.527660
# Hornet 4 Drive        1       131.4      High             Yes        0.468085
# Hornet Sportabout     2       193.7       Low              No        0.353191

# %% [markdown]
# ### 4.9 Extract First Word
# - Extract the first word from each car name (index) into a new column car_make using map() with a lambda.

# %%
df['car_make'] = df.index.map(lambda x: x.split()[0])
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  220  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  220  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0  186  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  220  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  350  3.15  3.440  17.02   0   0     3
#
#                    carb  mpg_hp_sum mpg_label efficient_power  mpg_normalized  \
# Mazda RX4             4       131.0      High             Yes        0.451064
# Mazda RX4 Wag         4       131.0      High             Yes        0.451064
# Datsun 710            1       115.8      High             Yes        0.527660
# Hornet 4 Drive        1       131.4      High             Yes        0.468085
# Hornet Sportabout     2       193.7       Low              No        0.353191
#
#                   car_make
# Mazda RX4            Mazda
# Mazda RX4 Wag        Mazda
# Datsun 710          Datsun
# Hornet 4 Drive      Hornet
# Hornet Sportabout   Hornet

# %% [markdown]
# ### 4.10 Square and Add
# - Create a column hp_mpg_calc = (hp² + mpg²) using apply() with a lambda.

# %%
df['hp_mpg_calc'] = df.apply(lambda row: (row['hp']*2) + (row['mpg']*2), axis=1)
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  220  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  220  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0  186  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  220  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  350  3.15  3.440  17.02   0   0     3
#
#                    carb  mpg_hp_sum mpg_label efficient_power  mpg_normalized  \
# Mazda RX4             4       131.0      High             Yes        0.451064
# Mazda RX4 Wag         4       131.0      High             Yes        0.451064
# Datsun 710            1       115.8      High             Yes        0.527660
# Hornet 4 Drive        1       131.4      High             Yes        0.468085
# Hornet Sportabout     2       193.7       Low              No        0.353191
#
#                   car_make  hp_mpg_calc
# Mazda RX4            Mazda        482.0
# Mazda RX4 Wag        Mazda        482.0
# Datsun 710          Datsun        417.6
# Hornet 4 Drive      Hornet        482.8
# Hornet Sportabout   Hornet        737.4

# %% [markdown]
# ### 4.11 Filter by Col values
# - Filter cars with mpg > 25.

# %%
df_filtered = df[df['mpg'] > 25]
df_filtered
# Out:
#                  mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb  \
# Fiat 128        32.4    4   78.7  132  4.08  2.200  19.47   1   1     4     1
# Honda Civic     30.4    4   75.7  104  4.93  1.615  18.52   1   1     4     2
# Toyota Corolla  33.9    4   71.1  130  4.22  1.835  19.90   1   1     4     1
# Fiat X1-9       27.3    4   79.0  132  4.08  1.935  18.90   1   1     4     1
# Porsche 914-2   26.0    4  120.3  182  4.43  2.140  16.70   0   1     5     2
# Lotus Europa    30.4    4   95.1  226  3.77  1.513  16.90   1   1     5     2
#
#                 mpg_hp_sum mpg_label efficient_power  mpg_normalized car_make  \
# Fiat 128              98.4      High             Yes        0.936170     Fiat
# Honda Civic           82.4      High             Yes        0.851064    Honda
# Toyota Corolla        98.9      High             Yes        1.000000   Toyota
# Fiat X1-9             93.3      High             Yes        0.719149     Fiat
# Porsche 914-2        117.0      High             Yes        0.663830  Porsche
# Lotus Europa         143.4      High             Yes        0.851064    Lotus
#
#                 hp_mpg_calc
# Fiat 128              328.8
# Honda Civic           268.8
# Toyota Corolla        327.8
# Fiat X1-9             318.6
# Porsche 914-2         416.0
# Lotus Europa          512.8

# %% [markdown]
# ### 4.12 Filter and soted carnames by horsepower
# - From above return a list of car names sorted by horsepower.

# %%
list(df_filtered.sort_values(by='hp').index)
# Out:
# ['Honda Civic',
#  'Toyota Corolla',
#  'Fiat 128',
#  'Fiat X1-9',
#  'Porsche 914-2',
#  'Lotus Europa']

# %% [raw]
# # End Here
# - docs - 1nWPAH4oD_DNP9lfJXtrlrgufld4YwYoJHVoNUtWZGS4
