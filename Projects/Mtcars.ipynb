# %%
import pandas as pd
import numpy as np
from pydataset import data 
df= data('mtcars')

# %%
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
df.shape
# Out:
# (32, 11)

# %%
df.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
df.dtypes
# Out:
# mpg     float64
# cyl       int64
# disp    float64
# hp        int64
# drat    float64
# wt      float64
# qsec    float64
# vs        int64
# am        int64
# gear      int64
# carb      int64
# dtype: object

# %%
df. describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# 25%    16.892500   0.000000   0.000000   3.000000   2.0000
# 50%    17.710000   0.000000   0.000000   4.000000   2.0000
# 75%    18.900000   1.000000   1.000000   4.000000   4.0000
# max    22.900000   1.000000   1.000000   5.000000   8.0000

# %%
df.isnull().sum()
# Out:
# mpg     0
# cyl     0
# disp    0
# hp      0
# drat    0
# wt      0
# qsec    0
# vs      0
# am      0
# gear    0
# carb    0
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# np.False_

# %%
df['mpg'].mean()
# Out:
# np.float64(20.090625000000003)

# %%
df['hp'].max()
# Out:
# 335

# %%
df['wt'].min()
# Out:
# 1.513

# %%
df['wt'].max()
# Out:
# 5.424

# %%
df['cyl'].value_counts().sort_index()
# Out:
# cyl
# 4    11
# 6     7
# 8    14
# Name: count, dtype: int64

# %%
df.groupby ('cyl') ['mpg'].mean()
# Out:
# cyl
# 4    26.663636
# 6    19.742857
# 8    15.100000
# Name: mpg, dtype: float64

# %%
df.groupby('am')['mpg'].mean()
# Out:
# am
# 0    17.147368
# 1    24.392308
# Name: mpg, dtype: float64

# %%
df.groupby('gear')['mpg'].mean()
# Out:
# gear
# 3    16.106667
# 4    24.533333
# 5    21.380000
# Name: mpg, dtype: float64

# %%
df.pivot_table(values= 'mpg',index='cyl',columns='am',aggfunc='mean')
# Out:
# am        0          1
# cyl
# 4    22.900  28.075000
# 6    19.125  20.566667
# 8    15.050  15.400000

# %%
df['efficiency']='low'
df.loc[df['mpg']>20,'eficiency']='high'

# %%
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb efficiency eficiency
# Mazda RX4             4        low      high
# Mazda RX4 Wag         4        low      high
# Datsun 710            1        low      high
# Hornet 4 Drive        1        low      high
# Hornet Sportabout     2        low       NaN

# %%
df['am']= df['am'].map({0:'Automatic',1:'Manual'})

# %%
df['vs']=df['vs'].map({0:'v-shaped',1:'Straight'})

# %%
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec        vs  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46  v-shaped
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02  v-shaped
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61  Straight
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44  Straight
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02  v-shaped
#
#                           am  gear  carb efficiency eficiency
# Mazda RX4             Manual     4     4        low      high
# Mazda RX4 Wag         Manual     4     4        low      high
# Datsun 710            Manual     4     1        low      high
# Hornet 4 Drive     Automatic     3     1        low      high
# Hornet Sportabout  Automatic     3     2        low       NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure (figsize=(8,5))
sns.barplot(x='cyl',y='mpg',data=df)
plt.title('Average mpg by cylinders')
plt.show()

# %%
sns.scatterplot(x='wt',y='mpg', data=df)
plt.title('Weight vs Mpg')
plt.show()

# %%
sns.histplot(df['hp'],bins=10,kde= True)
plt.title('Distribution of Horsepower')
plt.show()

# %%
sns.boxplot(x='am',y='mpg',data=df)
plt.title('Mpg by Transmission')
plt.show()
