# %%
#!pip install openpyxl #install this
#!pip install xlrd #install this
import numpy as np
import pandas as pd
import datetime as dt
#globalData
gExcel2='https://raw.githubusercontent.com/dupadhyaya/piit/main/data/Global_Superstore2.xlsx'
#gExcel2
gdata= pd.read_excel(gExcel2, engine="openpyxl")
gdata.shape
# Out:
# (51290, 24)

# %%
gdata.groupby(['Region'])['Shipping Cost'].agg('mean')
#avg shipping cost
# Out:
# Region
# Africa            19.215058
# Canada            19.285495
# Caribbean         21.059260
# Central           26.710494
# Central Asia      38.003003
# EMEA              17.573221
# East              25.542001
# North             27.476299
# North Asia        40.646112
# Oceania           34.593780
# South             25.353509
# Southeast Asia    29.937948
# West              23.887687
# Name: Shipping Cost, dtype: float64
