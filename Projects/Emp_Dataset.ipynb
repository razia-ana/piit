# %%
from sqlalchemy import create_engine, text
import pymysql
import pandas as pd 
import os

# %%
engine1= create_engine("mysql+pymysql://root:piit2025@localhost:3306/piit")

# %%
def q(sql, **params):
 with engine1.connect() as conn:
  return pd.read_sql(text(sql), conn, params=params)

# %%
q ("select * from emp where ename = 'rita'")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pymysql\cursors.py:157, in Cursor.execute(self, query, args)
# ...

# %%
q("select ename from emp where job in ('ANALYST','SALESMAN')")

# %%
q("select* from emp where hiredate < '1981-09-30'")

# %%
q("select ename from emp where job != 'MANAGER'")

# %%
q("select ename from emp where empno IN (7369, 7521, 7839, 7934, 7788)")

# %%
q("select * from emp WHERE deptno NOT IN (10, 30, 40)")

# %%
 q("select ename from emp where hiredate between '1981-06-30' and '1981-12-31'")

# %%
q("select distinct job from emp")

# %%
q("select ename from emp where comm is null or comm = 0")

# %%
q('select ename, job from emp where mgr is null')

# %%
q('select * from emp where deptno is null')

# %%
q('select ename from emp where comm is not null and comm > 0')

# %%
q("select ename from emp where ename like '%S' or ename like 'S%'")

# %%
q("select ename from emp where ename like '_i%'")

# %%
q('select count(*) as total_employees from emp')

# %%
q("select count(distinct job) as unique_job from emp")

# %%
q('select sum(sal) as total_payroll from emp')

# %%
q('select max(sal) as max_sal,min(sal) as min_sal, avg(sal) as avg_sal from emp')

# %%
q("select max(sal) from emp where job= 'SALESMAN'")
