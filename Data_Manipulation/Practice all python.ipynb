# %%
import pandas as pd
import numpy as np

# %%
pd.set_option ('display.max_columns',None)

# %%
from pydataset import data 
mtcars= data ('mtcars')
mtcars.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
','.join(data()['dataset_id'])
# Out:
# 'AirPassengers,BJsales,BOD,Formaldehyde,HairEyeColor,InsectSprays,JohnsonJohnson,LakeHuron,LifeCycleSavings,Nile,OrchardSprays,PlantGrowth,Puromycin,Titanic,ToothGrowth,UCBAdmissions,UKDriverDeaths,UKgas,USAccDeaths,USArrests,USJudgeRatings,USPersonalExpenditure,VADeaths,WWWusage,WorldPhones,airmiles,airquality,anscombe,attenu,attitude,austres,cars,chickwts,co2,crimtab,discoveries,esoph,euro,faithful,freeny,infert,iris,islands,lh,longley,lynx,morley,mtcars,nhtemp,nottem,npk,occupationalStatus,precip,presidents,pressure,quakes,randu,rivers,rock,sleep,stackloss,sunspot.month,sunspot.year,sunspots,swiss,treering,trees,uspop,volcano,warpbreaks,women,acme,aids,aircondit,aircondit7,amis,aml,bigcity,brambles,breslow,calcium,cane,capability,catsM,cav,cd4,channing,city,claridge,cloth,co.transfer,coal,darwin,dogs,downs.bc,ducks,fir,frets,grav,gravity,hirose,islay,manaus,melanoma,motor,neuro,nitrofen,nodal,nuclear,paulsen,poisons,polar,remission,salinity,survival,tau,tuna,urine,wool,aids,alloau
# ...

# %%
mtcars.sample(3)
# Out:
#                  mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# Fiat 128        32.4    4   78.7   66  4.08  2.200  19.47   1   1     4     1
# Honda Civic     30.4    4   75.7   52  4.93  1.615  18.52   1   1     4     2

# %%
data('iris').head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa
# 4           4.6          3.1           1.5          0.2  setosa
# 5           5.0          3.6           1.4          0.2  setosa

# %%
mtcars.dtypes
# Out:
# mpg     float64
# cyl       int64
# disp    float64
# hp        int64
# drat    float64
# wt      float64
# qsec    float64
# vs        int64
# am        int64
# gear      int64
# carb      int64
# dtype: object

# %%
mtcars.head(3)
# Out:
#                 mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# Mazda RX4      21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# Datsun 710     22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1

# %%
mtcars= data('mtcars')
mtcars= mtcars.astype({'cyl':'category','vs':'category','carb':'category','am':'category','gear':'category'})

# %%
mtcars.dtypes
# Out:
# mpg      float64
# cyl     category
# disp     float64
# hp         int64
# drat     float64
# wt       float64
# qsec     float64
# vs      category
# am      category
# gear    category
# carb    category
# dtype: object

# %%
mtcars.head()
# Out:
#                     mpg cyl   disp   hp  drat     wt   qsec vs am gear carb
# Mazda RX4          21.0   6  160.0  110  3.90  2.620  16.46  0  1    4    4
# Mazda RX4 Wag      21.0   6  160.0  110  3.90  2.875  17.02  0  1    4    4
# Datsun 710         22.8   4  108.0   93  3.85  2.320  18.61  1  1    4    1
# Hornet 4 Drive     21.4   6  258.0  110  3.08  3.215  19.44  1  0    3    1
# Hornet Sportabout  18.7   8  360.0  175  3.15  3.440  17.02  0  0    3    2

# %%
mtcars.describe(include='all')
# Out:
#               mpg   cyl        disp          hp       drat         wt  \
# count   32.000000  32.0   32.000000   32.000000  32.000000  32.000000
# unique        NaN   3.0         NaN         NaN        NaN        NaN
# top           NaN   8.0         NaN         NaN        NaN        NaN
# freq          NaN  14.0         NaN         NaN        NaN        NaN
# mean    20.090625   NaN  230.721875  146.687500   3.596563   3.217250
# std      6.026948   NaN  123.938694   68.562868   0.534679   0.978457
# min     10.400000   NaN   71.100000   52.000000   2.760000   1.513000
# 25%     15.425000   NaN  120.825000   96.500000   3.080000   2.581250
# 50%     19.200000   NaN  196.300000  123.000000   3.695000   3.325000
# 75%     22.800000   NaN  326.000000  180.000000   3.920000   3.610000
# max     33.900000   NaN  472.000000  335.000000   4.930000   5.424000
#
#              qsec    vs    am  gear  carb
# count   32.000000  32.0  32.0  32.0  32.0
# ...

# %%
mtcars['am']=mtcars['am'].map({0:'auto',1:'manual'})
mtcars.head()
# Out:
#                     mpg cyl   disp   hp  drat     wt   qsec vs      am gear  \
# Mazda RX4          21.0   6  160.0  110  3.90  2.620  16.46  0  manual    4
# Mazda RX4 Wag      21.0   6  160.0  110  3.90  2.875  17.02  0  manual    4
# Datsun 710         22.8   4  108.0   93  3.85  2.320  18.61  1  manual    4
# Hornet 4 Drive     21.4   6  258.0  110  3.08  3.215  19.44  1    auto    3
# Hornet Sportabout  18.7   8  360.0  175  3.15  3.440  17.02  0    auto    3
#
#                   carb
# Mazda RX4            4
# Mazda RX4 Wag        4
# Datsun 710           1
# Hornet 4 Drive       1
# Hornet Sportabout    2

# %%
mtcars['mpg'].max()
# Out:
# 33.9

# %%
mtcars[mtcars['mpg']>30].sort_values('mpg',ascending=False)
# Out:
#                  mpg cyl  disp   hp  drat     wt   qsec vs      am gear carb
# Toyota Corolla  33.9   4  71.1   65  4.22  1.835  19.90  1  manual    4    1
# Fiat 128        32.4   4  78.7   66  4.08  2.200  19.47  1  manual    4    1
# Honda Civic     30.4   4  75.7   52  4.93  1.615  18.52  1  manual    4    2
# Lotus Europa    30.4   4  95.1  113  3.77  1.513  16.90  1  manual    5    2

# %%
mtcars[mtcars['mpg']== mtcars['mpg'].max()]
# Out:
#                  mpg cyl  disp  hp  drat     wt  qsec vs      am gear carb
# Toyota Corolla  33.9   4  71.1  65  4.22  1.835  19.9  1  manual    4    1

# %%
mtcars[mtcars['mpg']<=mtcars['mpg'].mean()]
# Out:
#                       mpg cyl   disp   hp  drat     wt   qsec vs      am gear  \
# Hornet Sportabout    18.7   8  360.0  175  3.15  3.440  17.02  0    auto    3
# Valiant              18.1   6  225.0  105  2.76  3.460  20.22  1    auto    3
# Duster 360           14.3   8  360.0  245  3.21  3.570  15.84  0    auto    3
# Merc 280             19.2   6  167.6  123  3.92  3.440  18.30  1    auto    4
# Merc 280C            17.8   6  167.6  123  3.92  3.440  18.90  1    auto    4
# Merc 450SE           16.4   8  275.8  180  3.07  4.070  17.40  0    auto    3
# Merc 450SL           17.3   8  275.8  180  3.07  3.730  17.60  0    auto    3
# Merc 450SLC          15.2   8  275.8  180  3.07  3.780  18.00  0    auto    3
# Cadillac Fleetwood   10.4   8  472.0  205  2.93  5.250  17.98  0    auto    3
# Lincoln Continental  10.4   8  460.0  215  3.00  5.424  17.82  0    auto    3
# Chrysler Imperial    14.7   8  440.0  230  3.23  5.345  17.42  0    auto    3
# ...

# %%
mtcars['cyl'].unique()
# Out:
# [6, 4, 8]
# Categories (3, int64): [4, 6, 8]

# %%
mtcars['mpg'].unique()
# Out:
# array([21. , 22.8, 21.4, 18.7, 18.1, 14.3, 24.4, 19.2, 17.8, 16.4, 17.3,
#        15.2, 10.4, 14.7, 32.4, 30.4, 33.9, 21.5, 15.5, 13.3, 27.3, 26. ,
#        15.8, 19.7, 15. ])

# %%
mtcars['hp'].unique()
# Out:
# array([110,  93, 175, 105, 245,  62,  95, 123, 180, 205, 215, 230,  66,
#         52,  65,  97, 150,  91, 113, 264, 335, 109])

# %%
df=mtcars.groupby (['cyl','am']) ['hp'].mean().reset_index(name='avg')
df
# Out:
# C:\Users\rajia\AppData\Local\Temp\ipykernel_15604\3133682589.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df=mtcars.groupby (['cyl','am']) ['hp'].mean().reset_index(name='avg')
#   cyl      am         avg
# 0   4    auto   84.666667
# 1   4  manual   81.875000
# 2   6    auto  115.250000
# 3   6  manual  131.666667
# 4   8    auto  194.166667
# 5   8  manual  299.500000

# %%
df.rename(columns={'avg': 'avg_hp'})
# Out:
#   cyl      am      avg_hp
# 0   4    auto   84.666667
# 1   4  manual   81.875000
# 2   6    auto  115.250000
# 3   6  manual  131.666667
# 4   8    auto  194.166667
# 5   8  manual  299.500000

# %%
df.rename(columns={'avg_hp': 'avg'})
# Out:
#   cyl      am         avg
# 0   4    auto   84.666667
# 1   4  manual   81.875000
# 2   6    auto  115.250000
# 3   6  manual  131.666667
# 4   8    auto  194.166667
# 5   8  manual  299.500000

# %%
bins= [0,17,29,mtcars['mpg'].max()]
labels=['low','medium','high']
mtcars['mpg_label']=pd.cut(mtcars['mpg'],bins= bins, labels= labels, include_lowest= True)

# %%
mtcars.describe()
# Out:
#              mpg        disp          hp       drat         wt       qsec
# count  32.000000   32.000000   32.000000  32.000000  32.000000  32.000000
# mean   20.090625  230.721875  146.687500   3.596563   3.217250  17.848750
# std     6.026948  123.938694   68.562868   0.534679   0.978457   1.786943
# min    10.400000   71.100000   52.000000   2.760000   1.513000  14.500000
# 25%    15.425000  120.825000   96.500000   3.080000   2.581250  16.892500
# 50%    19.200000  196.300000  123.000000   3.695000   3.325000  17.710000
# 75%    22.800000  326.000000  180.000000   3.920000   3.610000  18.900000
# max    33.900000  472.000000  335.000000   4.930000   5.424000  22.900000

# %%
bins=[0,70,150,250,mtcars['hp'].max()]
labels=['low','medium','high','veryhigh']
mtcars['hp_label']=pd.cut(mtcars['hp'],bins= bins, labels= labels, include_lowest= True)

# %%
mtcars['hp_label']. value_counts()
# Out:
# hp_label
# medium      14
# high        11
# low          5
# veryhigh     2
# Name: count, dtype: int64

# %%
mtcars.head()
# Out:
#                     mpg cyl   disp   hp  drat     wt   qsec vs      am gear  \
# Mazda RX4          21.0   6  160.0  110  3.90  2.620  16.46  0  manual    4
# Mazda RX4 Wag      21.0   6  160.0  110  3.90  2.875  17.02  0  manual    4
# Datsun 710         22.8   4  108.0   93  3.85  2.320  18.61  1  manual    4
# Hornet 4 Drive     21.4   6  258.0  110  3.08  3.215  19.44  1    auto    3
# Hornet Sportabout  18.7   8  360.0  175  3.15  3.440  17.02  0    auto    3
#
#                   carb mpg_label hp_label
# Mazda RX4            4    medium   medium
# Mazda RX4 Wag        4    medium   medium
# Datsun 710           1    medium   medium
# Hornet 4 Drive       1    medium   medium
# Hornet Sportabout    2    medium     high

# %%
mtcars.groupby('mpg_label')['mpg'].count()
# Out:
# C:\Users\rajia\AppData\Local\Temp\ipykernel_15604\4268704863.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mtcars.groupby('mpg_label')['mpg'].count()
# mpg_label
# low       11
# medium    17
# high       4
# Name: mpg, dtype: int64

# %%
mtcars.mpg_label.value_counts ()
# Out:
# mpg_label
# medium    17
# low       11
# high       4
# Name: count, dtype: int64

# %%
mtcars['vs'] = mtcars['vs'].map({0: 'Vshaped', 1:'Straight'})
mtcars ['vs'].head()
# Out:
# Mazda RX4             Vshaped
# Mazda RX4 Wag         Vshaped
# Datsun 710           Straight
# Hornet 4 Drive       Straight
# Hornet Sportabout     Vshaped
# Name: vs, dtype: category
# Categories (2, object): ['Vshaped', 'Straight']

# %%
mtcars.head()
# Out:
#                     mpg cyl   disp   hp  drat     wt   qsec        vs      am  \
# Mazda RX4          21.0   6  160.0  110  3.90  2.620  16.46   Vshaped  manual
# Mazda RX4 Wag      21.0   6  160.0  110  3.90  2.875  17.02   Vshaped  manual
# Datsun 710         22.8   4  108.0   93  3.85  2.320  18.61  Straight  manual
# Hornet 4 Drive     21.4   6  258.0  110  3.08  3.215  19.44  Straight    auto
# Hornet Sportabout  18.7   8  360.0  175  3.15  3.440  17.02   Vshaped    auto
#
#                   gear carb mpg_label hp_label
# Mazda RX4            4    4    medium   medium
# Mazda RX4 Wag        4    4    medium   medium
# Datsun 710           4    1    medium   medium
# Hornet 4 Drive       3    1    medium   medium
# Hornet Sportabout    3    2    medium     high

# %%
mtcars['car_name']= mtcars.index

# %%
mtcars.head()
# Out:
#                     mpg cyl   disp   hp  drat     wt   qsec        vs      am  \
# Mazda RX4          21.0   6  160.0  110  3.90  2.620  16.46   Vshaped  manual
# Mazda RX4 Wag      21.0   6  160.0  110  3.90  2.875  17.02   Vshaped  manual
# Datsun 710         22.8   4  108.0   93  3.85  2.320  18.61  Straight  manual
# Hornet 4 Drive     21.4   6  258.0  110  3.08  3.215  19.44  Straight    auto
# Hornet Sportabout  18.7   8  360.0  175  3.15  3.440  17.02   Vshaped    auto
#
#                   gear carb mpg_label hp_label           car_name
# Mazda RX4            4    4    medium   medium          Mazda RX4
# Mazda RX4 Wag        4    4    medium   medium      Mazda RX4 Wag
# Datsun 710           4    1    medium   medium         Datsun 710
# Hornet 4 Drive       3    1    medium   medium     Hornet 4 Drive
# Hornet Sportabout    3    2    medium     high  Hornet Sportabout

# %%
mtcars.dtypes
# Out:
# mpg           float64
# cyl          category
# disp          float64
# hp              int64
# drat          float64
# wt            float64
# qsec          float64
# vs           category
# am           category
# gear         category
# carb         category
# mpg_label    category
# hp_label     category
# car_name       object
# dtype: object

# %%
print(len(mtcars[mtcars['mpg']>25]))
mtcars[mtcars['mpg']>25]
# Out:
# 6
#                  mpg cyl   disp   hp  drat     wt   qsec        vs      am  \
# Fiat 128        32.4   4   78.7   66  4.08  2.200  19.47  Straight  manual
# Honda Civic     30.4   4   75.7   52  4.93  1.615  18.52  Straight  manual
# Toyota Corolla  33.9   4   71.1   65  4.22  1.835  19.90  Straight  manual
# Fiat X1-9       27.3   4   79.0   66  4.08  1.935  18.90  Straight  manual
# Porsche 914-2   26.0   4  120.3   91  4.43  2.140  16.70   Vshaped  manual
# Lotus Europa    30.4   4   95.1  113  3.77  1.513  16.90  Straight  manual
#
#                gear carb mpg_label hp_label        car_name
# Fiat 128          4    1      high      low        Fiat 128
# Honda Civic       4    2      high      low     Honda Civic
# Toyota Corolla    4    1      high      low  Toyota Corolla
# Fiat X1-9         4    1    medium      low       Fiat X1-9
# Porsche 914-2     5    2    medium   medium   Porsche 914-2
# Lotus Europa      5    2      high   medium    Lotus Europa

# %%
mtcars[mtcars['mpg_label']== 'high']
# Out:
#                  mpg cyl  disp   hp  drat     wt   qsec        vs      am  \
# Fiat 128        32.4   4  78.7   66  4.08  2.200  19.47  Straight  manual
# Honda Civic     30.4   4  75.7   52  4.93  1.615  18.52  Straight  manual
# Toyota Corolla  33.9   4  71.1   65  4.22  1.835  19.90  Straight  manual
# Lotus Europa    30.4   4  95.1  113  3.77  1.513  16.90  Straight  manual
#
#                gear carb mpg_label hp_label        car_name
# Fiat 128          4    1      high      low        Fiat 128
# Honda Civic       4    2      high      low     Honda Civic
# Toyota Corolla    4    1      high      low  Toyota Corolla
# Lotus Europa      5    2      high   medium    Lotus Europa

# %%
mtcars[mtcars['hp_label'] == 'high']
# Out:
#                       mpg cyl   disp   hp  drat     wt   qsec       vs  \
# Hornet Sportabout    18.7   8  360.0  175  3.15  3.440  17.02  Vshaped
# Duster 360           14.3   8  360.0  245  3.21  3.570  15.84  Vshaped
# Merc 450SE           16.4   8  275.8  180  3.07  4.070  17.40  Vshaped
# Merc 450SL           17.3   8  275.8  180  3.07  3.730  17.60  Vshaped
# Merc 450SLC          15.2   8  275.8  180  3.07  3.780  18.00  Vshaped
# Cadillac Fleetwood   10.4   8  472.0  205  2.93  5.250  17.98  Vshaped
# Lincoln Continental  10.4   8  460.0  215  3.00  5.424  17.82  Vshaped
# Chrysler Imperial    14.7   8  440.0  230  3.23  5.345  17.42  Vshaped
# Camaro Z28           13.3   8  350.0  245  3.73  3.840  15.41  Vshaped
# Pontiac Firebird     19.2   8  400.0  175  3.08  3.845  17.05  Vshaped
# Ferrari Dino         19.7   6  145.0  175  3.62  2.770  15.50  Vshaped
#
#                          am gear carb mpg_label hp_label             car_name
# ...

# %%
mtcars[mtcars['wt'] >= 5]
# Out:
#                       mpg cyl   disp   hp  drat     wt   qsec       vs    am  \
# Cadillac Fleetwood   10.4   8  472.0  205  2.93  5.250  17.98  Vshaped  auto
# Lincoln Continental  10.4   8  460.0  215  3.00  5.424  17.82  Vshaped  auto
# Chrysler Imperial    14.7   8  440.0  230  3.23  5.345  17.42  Vshaped  auto
#
#                     gear carb mpg_label hp_label             car_name
# Cadillac Fleetwood     3    4       low     high   Cadillac Fleetwood
# Lincoln Continental    3    4       low     high  Lincoln Continental
# Chrysler Imperial      3    4       low     high    Chrysler Imperial

# %%
mtcars.query('mpg <23')
# Out:
#                       mpg cyl   disp   hp  drat     wt   qsec        vs  \
# Mazda RX4            21.0   6  160.0  110  3.90  2.620  16.46   Vshaped
# Mazda RX4 Wag        21.0   6  160.0  110  3.90  2.875  17.02   Vshaped
# Datsun 710           22.8   4  108.0   93  3.85  2.320  18.61  Straight
# Hornet 4 Drive       21.4   6  258.0  110  3.08  3.215  19.44  Straight
# Hornet Sportabout    18.7   8  360.0  175  3.15  3.440  17.02   Vshaped
# Valiant              18.1   6  225.0  105  2.76  3.460  20.22  Straight
# Duster 360           14.3   8  360.0  245  3.21  3.570  15.84   Vshaped
# Merc 230             22.8   4  140.8   95  3.92  3.150  22.90  Straight
# Merc 280             19.2   6  167.6  123  3.92  3.440  18.30  Straight
# Merc 280C            17.8   6  167.6  123  3.92  3.440  18.90  Straight
# Merc 450SE           16.4   8  275.8  180  3.07  4.070  17.40   Vshaped
# Merc 450SL           17.3   8  275.8  180  3.07  3.730  17.60   Vshaped
# ...

# %%
mtcars[mtcars['mpg'] <23] # we can write it down in both way with .query or like that both will show the same result
# query is a method used to filter rows using a condition as a string
# Out:
#                       mpg cyl   disp   hp  drat     wt   qsec        vs  \
# Mazda RX4            21.0   6  160.0  110  3.90  2.620  16.46   Vshaped
# Mazda RX4 Wag        21.0   6  160.0  110  3.90  2.875  17.02   Vshaped
# Datsun 710           22.8   4  108.0   93  3.85  2.320  18.61  Straight
# Hornet 4 Drive       21.4   6  258.0  110  3.08  3.215  19.44  Straight
# Hornet Sportabout    18.7   8  360.0  175  3.15  3.440  17.02   Vshaped
# Valiant              18.1   6  225.0  105  2.76  3.460  20.22  Straight
# Duster 360           14.3   8  360.0  245  3.21  3.570  15.84   Vshaped
# Merc 230             22.8   4  140.8   95  3.92  3.150  22.90  Straight
# Merc 280             19.2   6  167.6  123  3.92  3.440  18.30  Straight
# Merc 280C            17.8   6  167.6  123  3.92  3.440  18.90  Straight
# Merc 450SE           16.4   8  275.8  180  3.07  4.070  17.40   Vshaped
# Merc 450SL           17.3   8  275.8  180  3.07  3.730  17.60   Vshaped
# ...

# %%
mtcars.query('hp >150')
# Out:
#                       mpg cyl   disp   hp  drat     wt   qsec       vs  \
# Hornet Sportabout    18.7   8  360.0  175  3.15  3.440  17.02  Vshaped
# Duster 360           14.3   8  360.0  245  3.21  3.570  15.84  Vshaped
# Merc 450SE           16.4   8  275.8  180  3.07  4.070  17.40  Vshaped
# Merc 450SL           17.3   8  275.8  180  3.07  3.730  17.60  Vshaped
# Merc 450SLC          15.2   8  275.8  180  3.07  3.780  18.00  Vshaped
# Cadillac Fleetwood   10.4   8  472.0  205  2.93  5.250  17.98  Vshaped
# Lincoln Continental  10.4   8  460.0  215  3.00  5.424  17.82  Vshaped
# Chrysler Imperial    14.7   8  440.0  230  3.23  5.345  17.42  Vshaped
# Camaro Z28           13.3   8  350.0  245  3.73  3.840  15.41  Vshaped
# Pontiac Firebird     19.2   8  400.0  175  3.08  3.845  17.05  Vshaped
# Ford Pantera L       15.8   8  351.0  264  4.22  3.170  14.50  Vshaped
# Ferrari Dino         19.7   6  145.0  175  3.62  2.770  15.50  Vshaped
# ...

# %%
mtcars.query('mpg < 15 and hp >200')
# Out:
#                       mpg cyl   disp   hp  drat     wt   qsec       vs    am  \
# Duster 360           14.3   8  360.0  245  3.21  3.570  15.84  Vshaped  auto
# Cadillac Fleetwood   10.4   8  472.0  205  2.93  5.250  17.98  Vshaped  auto
# Lincoln Continental  10.4   8  460.0  215  3.00  5.424  17.82  Vshaped  auto
# Chrysler Imperial    14.7   8  440.0  230  3.23  5.345  17.42  Vshaped  auto
# Camaro Z28           13.3   8  350.0  245  3.73  3.840  15.41  Vshaped  auto
#
#                     gear carb mpg_label hp_label             car_name
# Duster 360             3    4       low     high           Duster 360
# Cadillac Fleetwood     3    4       low     high   Cadillac Fleetwood
# Lincoln Continental    3    4       low     high  Lincoln Continental
# Chrysler Imperial      3    4       low     high    Chrysler Imperial
# Camaro Z28             3    4       low     high           Camaro Z28

# %%
mtcars.filter (items=['hp','mpg'])
# Out:
#                       hp   mpg
# Mazda RX4            110  21.0
# Mazda RX4 Wag        110  21.0
# Datsun 710            93  22.8
# Hornet 4 Drive       110  21.4
# Hornet Sportabout    175  18.7
# Valiant              105  18.1
# Duster 360           245  14.3
# Merc 240D             62  24.4
# Merc 230              95  22.8
# Merc 280             123  19.2
# Merc 280C            123  17.8
# Merc 450SE           180  16.4
# Merc 450SL           180  17.3
# Merc 450SLC          180  15.2
# Cadillac Fleetwood   205  10.4
# Lincoln Continental  215  10.4
# Chrysler Imperial    230  14.7
# Fiat 128              66  32.4
# Honda Civic           52  30.4
# Toyota Corolla        65  33.9
# Toyota Corona         97  21.5
# Dodge Challenger     150  15.5
# AMC Javelin          150  15.2
# Camaro Z28           245  13.3
# Pontiac Firebird     175  19.2
# Fiat X1-9             66  27.3
# Porsche 914-2         91  26.0
# Lotus Europa         113  30.4
# Ford Pantera L       264  15.8
# ...

# %%
mtcars.filter(items= ['am','vs'])
# Out:
#                          am        vs
# Mazda RX4            manual   Vshaped
# Mazda RX4 Wag        manual   Vshaped
# Datsun 710           manual  Straight
# Hornet 4 Drive         auto  Straight
# Hornet Sportabout      auto   Vshaped
# Valiant                auto  Straight
# Duster 360             auto   Vshaped
# Merc 240D              auto  Straight
# Merc 230               auto  Straight
# Merc 280               auto  Straight
# Merc 280C              auto  Straight
# Merc 450SE             auto   Vshaped
# Merc 450SL             auto   Vshaped
# Merc 450SLC            auto   Vshaped
# Cadillac Fleetwood     auto   Vshaped
# Lincoln Continental    auto   Vshaped
# Chrysler Imperial      auto   Vshaped
# Fiat 128             manual  Straight
# Honda Civic          manual  Straight
# Toyota Corolla       manual  Straight
# Toyota Corona          auto  Straight
# Dodge Challenger       auto   Vshaped
# AMC Javelin            auto   Vshaped
# Camaro Z28             auto   Vshaped
# ...

# %%
mtcars[(mtcars['am'] == 'auto') &(mtcars['cyl']!='5') & (mtcars['mpg'] > 22)]
# Out:
#             mpg cyl   disp  hp  drat    wt  qsec        vs    am gear carb  \
# Merc 240D  24.4   4  146.7  62  3.69  3.19  20.0  Straight  auto    4    2
# Merc 230   22.8   4  140.8  95  3.92  3.15  22.9  Straight  auto    4    2
#
#           mpg_label hp_label   car_name
# Merc 240D    medium      low  Merc 240D
# Merc 230     medium   medium   Merc 230

# %%
mtcars.query("am == 'auto' and cyl != 5 and mpg >22") #same output we can write it down in both way
# Out:
# C:\Users\rajia\AppData\Local\Temp\ipykernel_15604\771190100.py:1: RuntimeWarning: Engine has switched to 'python' because numexpr does not support extension array dtypes. Please set your engine to python manually.
#   mtcars.query("am == 'auto' and cyl != 5 and mpg >22") #same output we can write it down in both way
#             mpg cyl   disp  hp  drat    wt  qsec        vs    am gear carb  \
# Merc 240D  24.4   4  146.7  62  3.69  3.19  20.0  Straight  auto    4    2
# Merc 230   22.8   4  140.8  95  3.92  3.15  22.9  Straight  auto    4    2
#
#           mpg_label hp_label   car_name
# Merc 240D    medium      low  Merc 240D
# Merc 230     medium   medium   Merc 230

# %%
mtcars[mtcars['mpg'].between(left= 23, right = 26.1, inclusive= 'left')]
# Out:
#                 mpg cyl   disp  hp  drat    wt  qsec        vs      am gear  \
# Merc 240D      24.4   4  146.7  62  3.69  3.19  20.0  Straight    auto    4
# Porsche 914-2  26.0   4  120.3  91  4.43  2.14  16.7   Vshaped  manual    5
#
#               carb mpg_label hp_label       car_name
# Merc 240D        2    medium      low      Merc 240D
# Porsche 914-2    2    medium   medium  Porsche 914-2

# %%
mtcars[mtcars['mpg'].between(23,30, inclusive= 'neither')]
# Out:
#                 mpg cyl   disp  hp  drat     wt  qsec        vs      am gear  \
# Merc 240D      24.4   4  146.7  62  3.69  3.190  20.0  Straight    auto    4
# Fiat X1-9      27.3   4   79.0  66  4.08  1.935  18.9  Straight  manual    4
# Porsche 914-2  26.0   4  120.3  91  4.43  2.140  16.7   Vshaped  manual    5
#
#               carb mpg_label hp_label       car_name
# Merc 240D        2    medium      low      Merc 240D
# Fiat X1-9        1    medium      low      Fiat X1-9
# Porsche 914-2    2    medium   medium  Porsche 914-2

# %%
mtcars[mtcars['mpg'].between(23,30) & (mtcars['am']== 'manual')]
# Out:
#                 mpg cyl   disp  hp  drat     wt  qsec        vs      am gear  \
# Fiat X1-9      27.3   4   79.0  66  4.08  1.935  18.9  Straight  manual    4
# Porsche 914-2  26.0   4  120.3  91  4.43  2.140  16.7   Vshaped  manual    5
#
#               carb mpg_label hp_label       car_name
# Fiat X1-9        1    medium      low      Fiat X1-9
# Porsche 914-2    2    medium   medium  Porsche 914-2

# %%
mtcars[mtcars['gear'].isin([4,5])] # list cars whose gear is in values 4,5
# Out:
#                  mpg cyl   disp   hp  drat     wt   qsec        vs      am  \
# Mazda RX4       21.0   6  160.0  110  3.90  2.620  16.46   Vshaped  manual
# Mazda RX4 Wag   21.0   6  160.0  110  3.90  2.875  17.02   Vshaped  manual
# Datsun 710      22.8   4  108.0   93  3.85  2.320  18.61  Straight  manual
# Merc 240D       24.4   4  146.7   62  3.69  3.190  20.00  Straight    auto
# Merc 230        22.8   4  140.8   95  3.92  3.150  22.90  Straight    auto
# Merc 280        19.2   6  167.6  123  3.92  3.440  18.30  Straight    auto
# Merc 280C       17.8   6  167.6  123  3.92  3.440  18.90  Straight    auto
# Fiat 128        32.4   4   78.7   66  4.08  2.200  19.47  Straight  manual
# Honda Civic     30.4   4   75.7   52  4.93  1.615  18.52  Straight  manual
# Toyota Corolla  33.9   4   71.1   65  4.22  1.835  19.90  Straight  manual
# Fiat X1-9       27.3   4   79.0   66  4.08  1.935  18.90  Straight  manual
# ...

# %%
mtcars[mtcars['gear'].isin([4,5]) | (mtcars['am'] =='auto')]# all auto or gear = 4,5
# Out:
#                       mpg cyl   disp   hp  drat     wt   qsec        vs  \
# Mazda RX4            21.0   6  160.0  110  3.90  2.620  16.46   Vshaped
# Mazda RX4 Wag        21.0   6  160.0  110  3.90  2.875  17.02   Vshaped
# Datsun 710           22.8   4  108.0   93  3.85  2.320  18.61  Straight
# Hornet 4 Drive       21.4   6  258.0  110  3.08  3.215  19.44  Straight
# Hornet Sportabout    18.7   8  360.0  175  3.15  3.440  17.02   Vshaped
# Valiant              18.1   6  225.0  105  2.76  3.460  20.22  Straight
# Duster 360           14.3   8  360.0  245  3.21  3.570  15.84   Vshaped
# Merc 240D            24.4   4  146.7   62  3.69  3.190  20.00  Straight
# Merc 230             22.8   4  140.8   95  3.92  3.150  22.90  Straight
# Merc 280             19.2   6  167.6  123  3.92  3.440  18.30  Straight
# Merc 280C            17.8   6  167.6  123  3.92  3.440  18.90  Straight
# Merc 450SE           16.4   8  275.8  180  3.07  4.070  17.40   Vshaped
# ...

# %%
mtcars[~mtcars['gear'].isin([4,5])]
# cars other gears values in 4,5 : ~ opposite
# Out:
#                       mpg cyl   disp   hp  drat     wt   qsec        vs    am  \
# Hornet 4 Drive       21.4   6  258.0  110  3.08  3.215  19.44  Straight  auto
# Hornet Sportabout    18.7   8  360.0  175  3.15  3.440  17.02   Vshaped  auto
# Valiant              18.1   6  225.0  105  2.76  3.460  20.22  Straight  auto
# Duster 360           14.3   8  360.0  245  3.21  3.570  15.84   Vshaped  auto
# Merc 450SE           16.4   8  275.8  180  3.07  4.070  17.40   Vshaped  auto
# Merc 450SL           17.3   8  275.8  180  3.07  3.730  17.60   Vshaped  auto
# Merc 450SLC          15.2   8  275.8  180  3.07  3.780  18.00   Vshaped  auto
# Cadillac Fleetwood   10.4   8  472.0  205  2.93  5.250  17.98   Vshaped  auto
# Lincoln Continental  10.4   8  460.0  215  3.00  5.424  17.82   Vshaped  auto
# Chrysler Imperial    14.7   8  440.0  230  3.23  5.345  17.42   Vshaped  auto
# Toyota Corona        21.5   4  120.1   97  3.70  2.465  20.01  Straight  auto
# ...

# %% [markdown]
# # select dtypes

# %%
mtcars.dtypes
# Out:
# mpg           float64
# cyl          category
# disp          float64
# hp              int64
# drat          float64
# wt            float64
# qsec          float64
# vs           category
# am           category
# gear         category
# carb         category
# mpg_label    category
# hp_label     category
# car_name       object
# dtype: object

# %%
mtcars.select_dtypes(include='number') # list columns which are numeric
# Out:
#                       mpg   disp   hp  drat     wt   qsec
# Mazda RX4            21.0  160.0  110  3.90  2.620  16.46
# Mazda RX4 Wag        21.0  160.0  110  3.90  2.875  17.02
# Datsun 710           22.8  108.0   93  3.85  2.320  18.61
# Hornet 4 Drive       21.4  258.0  110  3.08  3.215  19.44
# Hornet Sportabout    18.7  360.0  175  3.15  3.440  17.02
# Valiant              18.1  225.0  105  2.76  3.460  20.22
# Duster 360           14.3  360.0  245  3.21  3.570  15.84
# Merc 240D            24.4  146.7   62  3.69  3.190  20.00
# Merc 230             22.8  140.8   95  3.92  3.150  22.90
# Merc 280             19.2  167.6  123  3.92  3.440  18.30
# Merc 280C            17.8  167.6  123  3.92  3.440  18.90
# Merc 450SE           16.4  275.8  180  3.07  4.070  17.40
# Merc 450SL           17.3  275.8  180  3.07  3.730  17.60
# Merc 450SLC          15.2  275.8  180  3.07  3.780  18.00
# Cadillac Fleetwood   10.4  472.0  205  2.93  5.250  17.98
# ...

# %%
mtcars.select_dtypes(include='category').head()# list columns which category type
# Out:
#                   cyl        vs      am gear carb mpg_label hp_label
# Mazda RX4           6   Vshaped  manual    4    4    medium   medium
# Mazda RX4 Wag       6   Vshaped  manual    4    4    medium   medium
# Datsun 710          4  Straight  manual    4    1    medium   medium
# Hornet 4 Drive      6  Straight    auto    3    1    medium   medium
# Hornet Sportabout   8   Vshaped    auto    3    2    medium     high

# %%
mtcars.select_dtypes(include='object').head()# string, car names
# Out:
#                             car_name
# Mazda RX4                  Mazda RX4
# Mazda RX4 Wag          Mazda RX4 Wag
# Datsun 710                Datsun 710
# Hornet 4 Drive        Hornet 4 Drive
# Hornet Sportabout  Hornet Sportabout

# %% [markdown]
# # nlargest for a column

# %%
mtcars.nlargest(5,'mpg') # list cars which are among top 5 mpg
# Out:
#                  mpg cyl  disp   hp  drat     wt   qsec        vs      am  \
# Toyota Corolla  33.9   4  71.1   65  4.22  1.835  19.90  Straight  manual
# Fiat 128        32.4   4  78.7   66  4.08  2.200  19.47  Straight  manual
# Honda Civic     30.4   4  75.7   52  4.93  1.615  18.52  Straight  manual
# Lotus Europa    30.4   4  95.1  113  3.77  1.513  16.90  Straight  manual
# Fiat X1-9       27.3   4  79.0   66  4.08  1.935  18.90  Straight  manual
#
#                gear carb mpg_label hp_label        car_name
# Toyota Corolla    4    1      high      low  Toyota Corolla
# Fiat 128          4    1      high      low        Fiat 128
# Honda Civic       4    2      high      low     Honda Civic
# Lotus Europa      5    2      high   medium    Lotus Europa
# Fiat X1-9         4    1    medium      low       Fiat X1-9

# %%
mtcars.nsmallest(5,'wt')
# Out:
#                  mpg cyl   disp   hp  drat     wt   qsec        vs      am  \
# Lotus Europa    30.4   4   95.1  113  3.77  1.513  16.90  Straight  manual
# Honda Civic     30.4   4   75.7   52  4.93  1.615  18.52  Straight  manual
# Toyota Corolla  33.9   4   71.1   65  4.22  1.835  19.90  Straight  manual
# Fiat X1-9       27.3   4   79.0   66  4.08  1.935  18.90  Straight  manual
# Porsche 914-2   26.0   4  120.3   91  4.43  2.140  16.70   Vshaped  manual
#
#                gear carb mpg_label hp_label        car_name
# Lotus Europa      5    2      high   medium    Lotus Europa
# Honda Civic       4    2      high      low     Honda Civic
# Toyota Corolla    4    1      high      low  Toyota Corolla
# Fiat X1-9         4    1    medium      low       Fiat X1-9
# Porsche 914-2     5    2    medium   medium   Porsche 914-2

# %% [markdown]
# # sort values

# %%
mtcars.sort_values(by ='mpg', ascending = True, inplace= True)
# list mtcars by mpg, in increasing order

# %%
mtcars
# Out:
#                       mpg cyl   disp   hp  drat     wt   qsec        vs  \
# Lincoln Continental  10.4   8  460.0  215  3.00  5.424  17.82   Vshaped
# Cadillac Fleetwood   10.4   8  472.0  205  2.93  5.250  17.98   Vshaped
# Camaro Z28           13.3   8  350.0  245  3.73  3.840  15.41   Vshaped
# Duster 360           14.3   8  360.0  245  3.21  3.570  15.84   Vshaped
# Chrysler Imperial    14.7   8  440.0  230  3.23  5.345  17.42   Vshaped
# Maserati Bora        15.0   8  301.0  335  3.54  3.570  14.60   Vshaped
# Merc 450SLC          15.2   8  275.8  180  3.07  3.780  18.00   Vshaped
# AMC Javelin          15.2   8  304.0  150  3.15  3.435  17.30   Vshaped
# Dodge Challenger     15.5   8  318.0  150  2.76  3.520  16.87   Vshaped
# Ford Pantera L       15.8   8  351.0  264  4.22  3.170  14.50   Vshaped
# Merc 450SE           16.4   8  275.8  180  3.07  4.070  17.40   Vshaped
# Merc 450SL           17.3   8  275.8  180  3.07  3.730  17.60   Vshaped
# ...

# %%
mtcars.sort_values(['gear','mpg'])#.head()  #first by gear, mpg
# Out:
#                       mpg cyl   disp   hp  drat     wt   qsec        vs  \
# Lincoln Continental  10.4   8  460.0  215  3.00  5.424  17.82   Vshaped
# Cadillac Fleetwood   10.4   8  472.0  205  2.93  5.250  17.98   Vshaped
# Camaro Z28           13.3   8  350.0  245  3.73  3.840  15.41   Vshaped
# Duster 360           14.3   8  360.0  245  3.21  3.570  15.84   Vshaped
# Chrysler Imperial    14.7   8  440.0  230  3.23  5.345  17.42   Vshaped
# Merc 450SLC          15.2   8  275.8  180  3.07  3.780  18.00   Vshaped
# AMC Javelin          15.2   8  304.0  150  3.15  3.435  17.30   Vshaped
# Dodge Challenger     15.5   8  318.0  150  2.76  3.520  16.87   Vshaped
# Merc 450SE           16.4   8  275.8  180  3.07  4.070  17.40   Vshaped
# Merc 450SL           17.3   8  275.8  180  3.07  3.730  17.60   Vshaped
# Valiant              18.1   6  225.0  105  2.76  3.460  20.22  Straight
# Hornet Sportabout    18.7   8  360.0  175  3.15  3.440  17.02   Vshaped
# ...

# %%
mtcars.sort_values(['gear','mpg'], ascending= [False,True]) #.head()  #first by gear, mpg# gear:false:sorts gears from highest to lowest(decending)
#mpg:true: sorts mpg from lowest to highest(ascending)within each gear group.
# Out:
#                       mpg cyl   disp   hp  drat     wt   qsec        vs  \
# Maserati Bora        15.0   8  301.0  335  3.54  3.570  14.60   Vshaped
# Ford Pantera L       15.8   8  351.0  264  4.22  3.170  14.50   Vshaped
# Ferrari Dino         19.7   6  145.0  175  3.62  2.770  15.50   Vshaped
# Porsche 914-2        26.0   4  120.3   91  4.43  2.140  16.70   Vshaped
# Lotus Europa         30.4   4   95.1  113  3.77  1.513  16.90  Straight
# Merc 280C            17.8   6  167.6  123  3.92  3.440  18.90  Straight
# Merc 280             19.2   6  167.6  123  3.92  3.440  18.30  Straight
# Mazda RX4            21.0   6  160.0  110  3.90  2.620  16.46   Vshaped
# Mazda RX4 Wag        21.0   6  160.0  110  3.90  2.875  17.02   Vshaped
# Volvo 142E           21.4   4  121.0  109  4.11  2.780  18.60  Straight
# Merc 230             22.8   4  140.8   95  3.92  3.150  22.90  Straight
# Datsun 710           22.8   4  108.0   93  3.85  2.320  18.61  Straight
# ...

# %% [markdown]
# # pivot class

# %%
import pandas as pd
import numpy  as np
from pydataset import data
mtcars= data('mtcars')
mtcars.shape
# Out:
# (32, 11)

# %%
mtcars.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
mtcars.pivot_table(values='mpg',index='gear', observed = False)
# Mean mpg of Gear 3 cars is 16
# Out:
#             mpg
# gear
# 3     16.106667
# 4     24.533333
# 5     21.380000

# %%
mtcars.pivot_table(values= 'hp',index='cyl',observed= False)# mean hp of Cyl-4 cars is 82
# Out:
#              hp
# cyl
# 4     82.636364
# 6    122.285714
# 8    209.214286

# %%
mtcars.pivot_table(values=['mpg','hp'],index=['gear','am'],observed= False,
                   aggfunc=['sum','mean','count']).reset_index()
# Out:
#   gear am   sum               mean            count
#              hp    mpg          hp        mpg    hp mpg
# 0    3  0  2642  241.6  176.133333  16.106667    15  15
# 1    4  0   403   84.2  100.750000  21.050000     4   4
# 2    4  1   671  210.2   83.875000  26.275000     8   8
# 3    5  1   978  106.9  195.600000  21.380000     5   5

# %%
mtcars.pivot_table
# Out:
# <bound method DataFrame.pivot_table of                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
pd.pivot_table(data=mtcars, observed= False,
         index='gear',      #rows
         values='mpg',      #Values to summarize 
         aggfunc='median')    #Aggregation function
         # Median of Gear-3 cars is 15.5
# Out:
#        mpg
# gear
# 3     15.5
# 4     22.8
# 5     19.7

# %%
pd.pivot_table= pd.pivot_table(
    data=mtcars, observed= False,
    index='gear',
    columns='am',
    values='mpg',
    aggfunc='mean'
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 pd.pivot_table= pd.pivot_table(
#       2     data=mtcars, observed= False,
#       3     index='gear',
#       4     columns='am',
#       5     values='mpg',
#       6     aggfunc='mean'
#       7 )
#
# TypeError: 'DataFrame' object is not callable
