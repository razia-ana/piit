# %%
x3 = {'brand':'Honda', 'model':'Jazz', 'year':2017, 'hp': 3}
x3
# Out:
# {'brand': 'Honda', 'model': 'Jazz', 'year': 2017, 'hp': 3}

# %%
type(x3)
# Out:
# dict

# %%
x3['hp']
# Out:
# 3

# %%
print (x3['model'])
# Out:
# Jazz

# %%
print(x3['year'])
# Out:
# 2017

# %%
print(dir(x3), sep= '\t')
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
x3b= {'Firstname': 'Razia', 'Lastname': 'Sultana', 'Gender': 'F', 'Orgin': ' Bangladesh', 'City':'Egg harbor', 'State':'new jersey'}
x3b
# Out:
# {'Firstname': 'Razia',
#  'Lastname': 'Sultana',
#  'Gender': 'F',
#  'Orgin': ' Bangladesh',
#  'City': 'Egg harbor',
#  'State': 'new jersey'}

# %%
x3b['Gender']
# Out:
# 'F'

# %%
x3b= {'Firstname': 'Razia', 'Lastname': 'Sultana', 'Gender': 'F', 'Orgin': ' Bangladesh', 'City':'Egg harbor', 'State':'new jersey'}
x3b
# Out:
# {'Firstname': 'Razia',
#  'Lastname': 'Sultana',
#  'Gender': 'F',
#  'Orgin': ' Bangladesh',
#  'City': 'Egg harbor',
#  'State': 'new jersey'}

# %%
x4b= {'fristname': 'rita'}
x4b
# Out:
# {'fristname': 'rita'}

# %%
x3b
# Out:
# {'Firstname': 'Razia',
#  'Lastname': 'Sultana',
#  'Gender': 'F',
#  'Orgin': ' Bangladesh',
#  'City': 'Egg harbor',
#  'State': 'new jersey'}
