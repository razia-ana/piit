# %% [markdown]
# ## blending

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pprint import pformat

# %%
#copy data from clipboard
students = pd.read_clipboard(sep='\t')
students.shape
# Out:
# (25, 11)

# %%
students
# Out:
#     RollNo       Name Gender Program       State  English  Maths  Python  \
# 0     1001       Alex      M   BTech  California       78     91      88
# 1     1002       Emma      F   BTech  California       84     95      92
# 2     1003       Liam      M     BBA       Texas       75     72      68
# 3     1004     Olivia      F    BCom     Florida       88     76      74
# 4     1005       Noah      M   BTech       Texas       69     86      90
# 5     1006        Ava      F     BBA  California       91     83      80
# 6     1007      Ethan      M    BCom     Florida       73     68      65
# 7     1008     Sophia      F   BTech       Texas       86     94      95
# 8     1009      Mason      M     BBA  California       80     77      72
# 9     1010   Isabella      F    BCom     Florida       92     81      78
# 10    1011      James      M   BTech  California       77     89      91
# 11    1012        Mia      F     BBA       Texas       83     75      71
# 12    1013   Benjamin      M    BCom     Florida       70     66      63
# 13    1014  Charlotte      F   BTech       Texas       89     97      96
# 14    1015      Lucas      M     BBA  California       81     79      75
# 15    1016     Amelia      F    BCom     Florida       90     84      79
# 16    1017      Henry      M   BTech  California       76     88      87
# 17    1018     Harper      F     BBA       Texas       87     82      81
# 18    1019  Alexander      M    BCom     Florida       72     69      67
# 19    1020     Evelyn      F   BTech  California       94     96      98
# 20    1021     Daniel      M     BBA       Texas       79     74      70
# 21    1022    Abigail      F    BCom     Florida       85     80      76
# 22    1023    Michael      M   BTech       Texas       74     87      89
# 23    1024       Ella      F     BBA  California       93     85      83
# 24    1025      Jacob      M    BCom     Florida       71     67      64
#
#     Tableau  FeeTBP  FeePaid
# 0        82   18000    14000
# 1        90   18000    13000
# 2        70   12000    10000
# 3        79   10000     9000
# 4        87   18000    17000
# 5        85   12000    11000
# 6        69   10000     9000
# 7        93   18000    17000
# 8        74   12000    10000
# 9        83   10000     8000
# 10       88   18000    17000
# 11       76   12000    11000
# 12       67   10000     9000
# 13       95   18000    14000
# 14       77   12000    11000
# 15       82   10000     7000
# 16       84   18000    17000
# 17       86   12000    11000
# 18       71   10000     9000
# 19       97   18000    16000
# 20       73   12000    10000
# 21       81   10000     9000
# 22       86   18000    16000
# 23       88   12000     9000
# 24       68   10000     8000

# %%
#copy target data : goto sheet
targets = pd.read_clipboard(sep='\t')
targets.shape
# Out:
# (3, 5)

# %%
targets
# Out:
#   Program  Target  AnnualFee  Faculty  Budget
# 0   BTech      20      18000       45  360000
# 1     BBA      15      12000       25  180000
# 2    BCom      12      10000       18  120000

# %%
students['TotalMarks'] = students['English'] + students['Maths'] + students['Python'] + students['Tableau']
students.head()
# Out:
#    RollNo    Name Gender Program       State  English  Maths  Python  Tableau  \
# 0    1001    Alex      M   BTech  California       78     91      88       82
# 1    1002    Emma      F   BTech  California       84     95      92       90
# 2    1003    Liam      M     BBA       Texas       75     72      68       70
# 3    1004  Olivia      F    BCom     Florida       88     76      74       79
# 4    1005    Noah      M   BTech       Texas       69     86      90       87
#
#    FeeTBP  FeePaid  TotalMarks
# 0   18000    14000         339
# 1   18000    13000         361
# 2   12000    10000         285
# 3   10000     9000         317
# 4   18000    17000         332

# %%
students['avgPython'] = students.groupby('Program')['Python'].transform('mean').round(1)
students.head()
# Out:
#    RollNo    Name Gender Program       State  English  Maths  Python  Tableau  \
# 0    1001    Alex      M   BTech  California       78     91      88       82
# 1    1002    Emma      F   BTech  California       84     95      92       90
# 2    1003    Liam      M     BBA       Texas       75     72      68       70
# 3    1004  Olivia      F    BCom     Florida       88     76      74       79
# 4    1005    Noah      M   BTech       Texas       69     86      90       87
#
#    FeeTBP  FeePaid  TotalMarks  avgPython
# 0   18000    14000         339       91.8
# 1   18000    13000         361       91.8
# 2   12000    10000         285       75.0
# 3   10000     9000         317       70.8
# 4   18000    17000         332       91.8

# %%
## LOD : {FIXED [Program] : AVG([TotalMarks]) }
lod2 = students.groupby('Program').agg({'TotalMarks':'mean'}).reset_index().round(1)
lod2
# Out:
#   Program  TotalMarks
# 0     BBA       315.6
# 1    BCom       299.8
# 2   BTech       353.1

# %%
# Difference of Total Marks against Average Marks of class depending upon the program
students['progAvg'] = students.groupby('Program')['TotalMarks'].transform('mean').round(1)
students.head()
# Out:
#    RollNo    Name Gender Program       State  English  Maths  Python  Tableau  \
# 0    1001    Alex      M   BTech  California       78     91      88       82
# 1    1002    Emma      F   BTech  California       84     95      92       90
# 2    1003    Liam      M     BBA       Texas       75     72      68       70
# 3    1004  Olivia      F    BCom     Florida       88     76      74       79
# 4    1005    Noah      M   BTech       Texas       69     86      90       87
#
#    FeeTBP  FeePaid  TotalMarks  avgPython  progAvg
# 0   18000    14000         339       91.8    353.1
# 1   18000    13000         361       91.8    353.1
# 2   12000    10000         285       75.0    315.6
# 3   10000     9000         317       70.8    299.8
# 4   18000    17000         332       91.8    353.1

# %%
students["Diff_Total_progAvg"] = ( students["TotalMarks"] - students["progAvg"])
students.head()
# Out:
#    RollNo    Name Gender Program       State  English  Maths  Python  Tableau  \
# 0    1001    Alex      M   BTech  California       78     91      88       82
# 1    1002    Emma      F   BTech  California       84     95      92       90
# 2    1003    Liam      M     BBA       Texas       75     72      68       70
# 3    1004  Olivia      F    BCom     Florida       88     76      74       79
# 4    1005    Noah      M   BTech       Texas       69     86      90       87
#
#    FeeTBP  FeePaid  TotalMarks  avgPython  progAvg  Diff_Total_progAvg
# 0   18000    14000         339       91.8    353.1               -14.1
# 1   18000    13000         361       91.8    353.1                 7.9
# 2   12000    10000         285       75.0    315.6               -30.6
# 3   10000     9000         317       70.8    299.8                17.2
# 4   18000    17000         332       91.8    353.1               -21.1

# %%
students.groupby('Program').agg({'RollNo':'count', 'FeePaid':'sum'}).round(1).reset_index()
# Out:
#   Program  RollNo  FeePaid
# 0     BBA       8    83000
# 1    BCom       8    68000
# 2   BTech       9   141000

# %%
#Expressions Way
aggrExpr = {'Admissions' : ('RollNo', 'count'), 'FeeCollected' :('FeePaid','sum')}
students.groupby('Program').agg(**aggrExpr).round(1).reset_index()
# Out:
#   Program  Admissions  FeeCollected
# 0     BBA           8         83000
# 1    BCom           8         68000
# 2   BTech           9        141000

# %%
# Group1
blend1 = students.groupby('Program').agg(Admissions = ('RollNo', 'count'), FeeCollected = ('FeePaid','sum')).round(0).reset_index()
blend1
# Out:
#   Program  Admissions  FeeCollected
# 0     BBA           8         83000
# 1    BCom           8         68000
# 2   BTech           9        141000

# %%
targets
# Out:
#   Program  Target  AnnualFee  Faculty  Budget
# 0   BTech      20      18000       45  360000
# 1     BBA      15      12000       25  180000
# 2    BCom      12      10000       18  120000

# %%
blend2 = targets.copy()
blend2
# Out:
#   Program  Target  AnnualFee  Faculty  Budget
# 0   BTech      20      18000       45  360000
# 1     BBA      15      12000       25  180000
# 2    BCom      12      10000       18  120000

# %%
blending = pd.merge(blend1, blend2, on='Program')
blending
# Out:
#   Program  Admissions  FeeCollected  Target  AnnualFee  Faculty  Budget
# 0     BBA           8         83000      15      12000       25  180000
# 1    BCom           8         68000      12      10000       18  120000
# 2   BTech           9        141000      20      18000       45  360000

# %%
# Pipeline style adding columns
blending.assign(admAch = lambda x: round(100 * x['Admissions'] / x['Target']),budgetAch = lambda x : round(100 * x['FeeCollected']/x['Budget']))
# Out:
#   Program  Admissions  FeeCollected  Target  AnnualFee  Faculty  Budget  \
# 0     BBA           8         83000      15      12000       25  180000
# 1    BCom           8         68000      12      10000       18  120000
# 2   BTech           9        141000      20      18000       45  360000
#
#    admAch  budgetAch
# 0    53.0       46.0
# 1    67.0       57.0
# 2    45.0       39.0

# %%
blending['Productivity_Adm'] = blending['Admissions'] / blending['Target']
blending
# Out:
#   Program  Admissions  FeeCollected  Target  AnnualFee  Faculty  Budget  \
# 0     BBA           8         83000      15      12000       25  180000
# 1    BCom           8         68000      12      10000       18  120000
# 2   BTech           9        141000      20      18000       45  360000
#
#    Productivity_Adm
# 0          0.533333
# 1          0.666667
# 2          0.450000

# %%
30000/80000
# Out:
# 0.375
