# %%
from sqlalchemy import create_engine, text
import pymysql
import numpy as np
from pydataset import data
import pydataset
import pandas as pd 
import os

# %%
engine1 = create_engine("mysql+pymysql://root:piit2025@localhost:3306/adventureworks")

# %%
def q(sql, **params):
 with engine1.connect() as conn:
  return pd.read_sql(text(sql), conn, params=params)

# %%
q('show tables')
# Out:
#                  Tables_in_adventureworks
# 0                                 address
# 1                             addresstype
# 2                          awbuildversion
# 3                         billofmaterials
# 4                                 contact
# 5                       contactcreditcard
# 6                             contacttype
# 7                           countryregion
# 8                   countryregioncurrency
# 9                              creditcard
# 10                                culture
# 11                               currency
# 12                           currencyrate
# 13                               customer
# 14                        customeraddress
# 15                            databaselog
# 16                             department
# 17                               document
# 18                               employee
# 19                        employeeaddress
# 20              employeedepartmenthistory
# ...

# %%
dep = q("select * from department")
dep
# Out:
#     DepartmentID                        Name  \
# 0              1                 Engineering
# 1              2                 Tool Design
# 2              3                       Sales
# 3              4                   Marketing
# 4              5                  Purchasing
# 5              6    Research and Development
# 6              7                  Production
# 7              8          Production Control
# 8              9             Human Resources
# 9             10                     Finance
# 10            11        Information Services
# 11            12            Document Control
# 12            13           Quality Assurance
# 13            14  Facilities and Maintenance
# 14            15      Shipping and Receiving
# 15            16                   Executive
#
#                                GroupName        ModifiedDate
# 0               Research and Development 1998-05-31 18:00:00
# 1               Research and Development 1998-05-31 18:00:00
# ...

# %%
dep = q( "select name from department")
dep
# Out:
#                           name
# 0                  Engineering
# 1                  Tool Design
# 2                        Sales
# 3                    Marketing
# 4                   Purchasing
# 5     Research and Development
# 6                   Production
# 7           Production Control
# 8              Human Resources
# 9                      Finance
# 10        Information Services
# 11            Document Control
# 12           Quality Assurance
# 13  Facilities and Maintenance
# 14      Shipping and Receiving
# 15                   Executive

# %%
dep = q("select groupname from department")
dep
# Out:
#                                groupname
# 0               Research and Development
# 1               Research and Development
# 2                    Sales and Marketing
# 3                    Sales and Marketing
# 4                   Inventory Management
# 5               Research and Development
# 6                          Manufacturing
# 7                          Manufacturing
# 8   Executive General and Administration
# 9   Executive General and Administration
# 10  Executive General and Administration
# 11                     Quality Assurance
# 12                     Quality Assurance
# 13  Executive General and Administration
# 14                  Inventory Management
# 15  Executive General and Administration

# %%
dep= q("select distinct groupname from department")
dep
# Out:
#                               groupname
# 0              Research and Development
# 1                   Sales and Marketing
# 2                  Inventory Management
# 3                         Manufacturing
# 4  Executive General and Administration
# 5                     Quality Assurance

# %%
dep= q("select name from department where groupname = 'Manufacturing'")
dep
# Out:
#                  name
# 0          Production
# 1  Production Control

# %%
q("select * from employee")
# Out:
#      EmployeeID NationalIDNumber  ContactID                   LoginID  \
# 0             1         14417807       1209      adventure-works\guy1
# 1             2        253022876       1030    adventure-works\kevin0
# 2             3        509647174       1002  adventure-works\roberto0
# 3             4        112457891       1290      adventure-works\rob0
# 4             5        480168528       1009  adventure-works\thierry0
# ..          ...              ...        ...                       ...
# 285         286        134219713       1022   adventure-works\ranjit0
# 286         287         90836195       1027     adventure-works\tete0
# 287         288        481044938       1012     adventure-works\syed0
# 288         289        954276278       1023   adventure-works\rachel0
# 289         290        758596752       1024     adventure-works\lynn0
#
#      ManagerID                         Title  BirthDate MaritalStatus Gender  \
# ...

# %%
emp=q("select * from employee where ManagerID in (2,3)")
emp
# Out:
#    EmployeeID NationalIDNumber  ContactID                   LoginID  \
# 0           4        112457891       1290      adventure-works\rob0
# 1           9        695256908       1005     adventure-works\gail0
# 2          11        998320692       1006   adventure-works\jossef0
# 3         158        134969118       1049    adventure-works\dylan0
# 4         263        974026903       1007   adventure-works\ovidiu0
# 5         267         42487730       1003  adventure-works\michael8
# 6         270         56920285       1004   adventure-works\sharon0
#
#    ManagerID                             Title  BirthDate MaritalStatus  \
# 0          3              Senior Tool Designer 1965-01-23             S
# 1          3                   Design Engineer 1942-10-29             M
# 2          3                   Design Engineer 1949-04-11             M
# 3          3  Research and Development Manager 1977-03-27             M
# ...

# %%
emp=q("SELECT * FROM employee WHERE title ='Facilities manager'")
emp
# Out:
#    EmployeeID NationalIDNumber  ContactID                LoginID  ManagerID  \
# 0         218        141165819       1274  adventure-works\gary1        148
#
#                 Title  BirthDate MaritalStatus Gender   HireDate SalariedFlag  \
# 0  Facilities Manager 1961-03-21             M      M 2000-01-03      b'\x01'
#
#    VacationHours  SickLeaveHours CurrentFlag  \
# 0             86              63     b'\x01'
#
#                                              rowguid        ModifiedDate
# 0  b'Y\xc3\xac\xc3\xb6b5V\xc3\xb3D\xc2\x9c\xc3\x81-' 2004-07-30 18:00:00

# %%
emp=q("SELECT * FROM employee WHERE title like 'Facilities manager'")
emp
# Out:
#    EmployeeID NationalIDNumber  ContactID                LoginID  ManagerID  \
# 0         218        141165819       1274  adventure-works\gary1        148
#
#                 Title  BirthDate MaritalStatus Gender   HireDate SalariedFlag  \
# 0  Facilities Manager 1961-03-21             M      M 2000-01-03      b'\x01'
#
#    VacationHours  SickLeaveHours CurrentFlag  \
# 0             86              63     b'\x01'
#
#                                              rowguid        ModifiedDate
# 0  b'Y\xc3\xac\xc3\xb6b5V\xc3\xb3D\xc2\x9c\xc3\x81-' 2004-07-30 18:00:00

# %%
emp=q("SELECT Title FROM employee WHERE title like'%manager'")
emp
# Out:
#                                Title
# 0                Engineering Manager
# 1                  Marketing Manager
# 2         Production Control Manager
# 3            Human Resources Manager
# 4       Information Services Manager
# 5                    Finance Manager
# 6           Document Control Manager
# 7                   Accounts Manager
# 8                    Network Manager
# 9   Research and Development Manager
# 10         Quality Assurance Manager
# 11  Research and Development Manager
# 12                Facilities Manager
# 13      North American Sales Manager
# 14                Purchasing Manager
# 15            European Sales Manager
# 16             Pacific Sales Manager

# %%
emp=q("select * from employee where BirthDate > '1980-01-01'")
emp
# Out:
#     EmployeeID NationalIDNumber  ContactID                     LoginID  \
# 0           37        276751903       1226      adventure-works\simon0
# 1           54        540688287       1264     adventure-works\tengiz0
# 2           99        830150469       1158    adventure-works\michael1
# 3          115        886023130       1094       adventure-works\paul1
# 4          120        563680513       1180     adventure-works\angela0
# 5          136        167554340       1175     adventure-works\kathie0
# 6          155        377784364       1165       adventure-works\alex0
# 7          159        551834634       1063      adventure-works\shane0
# 8          172        273260055       1160      adventure-works\baris0
# 9          174        752513276       1219      adventure-works\steve0
# 10         179        599942664       1187       adventure-works\chad0
# 11         202        912141525       1193  adventure-works\elizabeth0
#
# ...

# %%
emp=q("SELECT * FROM Employee WHERE BirthDate BETWEEN '1970-1-1' AND '1980-1-1'")
emp
# Out:
#      EmployeeID NationalIDNumber  ContactID                       LoginID  \
# 0             1         14417807       1209          adventure-works\guy1
# 1             2        253022876       1030        adventure-works\kevin0
# 2            21        277173473       1231        adventure-works\peter0
# 3            25        360868122       1054        adventure-works\zheng0
# 4            26        964089218       1097          adventure-works\ivo0
# 5            27        384162788       1156         adventure-works\paul0
# 6            29        571658797       1199      adventure-works\kendall0
# 7            31        761597760       1140    adventure-works\alejandro0
# 8            32        271438431       1122      adventure-works\garrett0
# 9            33        160739235       1124     adventure-works\jianshuo0
# 10           38        630184120       1065      adventure-works\jinghao0
# 11           39        545337468       1108      adventure-works\michael0
# ...
