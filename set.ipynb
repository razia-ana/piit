# %%
groupA= set(['Bangladesh','England','Usa','Spain','India'])
groupB= set(['India','France','Poland','India'])

# %%
print(type(groupA), type(groupB))
# Out:
# <class 'set'> <class 'set'>

# %%
print(groupA, "\n", groupB)
# Out:
# {'England', 'Usa', 'Bangladesh', 'Spain', 'India'}
#  {'India', 'Poland', 'France'}

# %%
groupA.union(groupB)
# Out:
# {'Bangladesh', 'England', 'France', 'India', 'Poland', 'Spain', 'Usa'}

# %%
groupA.intersection(groupB)
# Out:
# {'India'}

# %%
groupA-groupB
# Out:
# {'Bangladesh', 'England', 'Spain', 'Usa'}

# %%
groupB-groupA
# Out:
# {'France', 'Poland'}

# %%
groupA| groupB
# Out:
# {'Bangladesh', 'England', 'France', 'India', 'Poland', 'Spain', 'Usa'}

# %%
groupA & groupB
# Out:
# {'India'}

# %%
groupA ^ groupB
# Out:
# {'Bangladesh', 'England', 'France', 'Poland', 'Spain', 'Usa'}
